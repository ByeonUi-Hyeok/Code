# %% [markdown]
# # 기본

# %% [markdown]
#  - 파이썬
#     - IDE(개발통합환경)
#        - 전용툴
#           - 파이XX(파이로시작하는 대부분) : ex)파이데브, 기본 파이썬 IDE
#        - 범용툴
#           - ***VScode***, elipse
#        - 위 툴들은***파이썬 기반으로 어플리케이션 제작시 사용***
#     - 대화형 (*.ipynb = ipython notebook)
#        - IPython (대화형의 기본 툴) 명령어 다외워야함 생산성 떨어짐
#        - IPython + fkask = 웹환경 구축 = jupyter notebook or jupyter lab
#           - jupyter lab은 쥬피터 노트북 보다 상위?
#        - *Google colab*

# %% [markdown]
#  - 기본설치
#     - Case 1. Python.org에서 다운로드
#     - Case 2. anaconda / Miniconda 등 풀패키지 인스톨러로 설치
#        - 자주 사용하는 모듈(라이브러리)가 이미 설치되어 있다.
#        - 모든 프로젝트는 ***가상환경***을 구축해서 진행한다.
#           - 버전 충돌이 나지않게 가상환경...을씀?

# %% [markdown]
# # 딥러닝

# %% [markdown]
#  - 딥러닝 서버 구축 필수
#  - 구글의 코랩은 이미 구축되어 있다. 단 id 당총 양 12시간 제약

# %% [markdown]
# # 필기
#  - !는 매직코드로 운영체제에게 바로 명령을 보내는 것..?
#  - 매직코드의 문법은 ! 명령어 이다.
#  - 코랩은 운영체제 내부를 볼 수 없고 브라우져 뿐없기때문에 매직코드 사용했다.
#  - 실행하면 리눅스가 할당되어 보여줌.
#  - !pip list는 현재 환경에 설치되어 있는 라이브러리(공식명칭:모듈) 보여달라 는 명령어
